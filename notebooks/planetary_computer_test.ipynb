# %%
from pystac.extensions.eo import EOExtension as eo
import pystac_client
import planetary_computer

# %%
from satellite_imagery_viewer.stac.normalizer import (
    normalize_stac_item_to_imagery_search_response,
)

# %%
import truststore
truststore.inject_into_ssl()

# %%
catalog = pystac_client.Client.open(
    "https://planetarycomputer.microsoft.com/api/stac/v1",
    modifier=planetary_computer.sign_inplace,
)

# %%
area_of_interest = {
    "type": "Polygon",
    "coordinates": [
        [
            [-148.56536865234375, 60.80072385643073],
            [-147.44338989257812, 60.80072385643073],
            [-147.44338989257812, 61.18363894915102],
            [-148.56536865234375, 61.18363894915102],
            [-148.56536865234375, 60.80072385643073],
        ]
    ],
}

# %%
time_of_interest = "2019-06-01/2019-08-01"

# %%
search = catalog.search(
    collections=["sentinel-2-l2a"],
    intersects=area_of_interest,
    datetime=time_of_interest,
    query={"eo:cloud_cover": {"lt": 10}},
)

items = search.item_collection()

print("SENTINEL-2")
print("Count:", len(items))

item = items[0]

from pprint import pprint

pprint(item.to_dict())
print("ID:", item.id)
print("Collection:", item.collection_id)
print("Properties:", item.properties)
print("Assets:", item.assets.keys())
# Out:
# SENTINEL-2
# Count: 5
# {'assets': {'AOT': {'gsd': 10.0,
#                     'href': 'https://sentinel2l2a01.blob.core.windows.net/sentinel2-l2/06/V/VN/2019/07/17/S2A_MSIL2A_20190717T213531_N0212_R086_T06VVN_20201005T152616.SAFE/GRANULE/L2A_T06VVN_A021247_20190717T213556/IMG_DATA/R10m/T06VVN_20190717T213531_AOT_10m.tif?st=2026-09-03T10%3A37%3A22Z&se=2026-09-04T11%3A22%3A22Z&sp=rl&sv=2025-07-05&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2026-09-04T10%3A28%3A44Z&ske=2026-09-11T10%3A28%3A44Z&sks=b&skv=2025-07-05&sig=RFsXlk2EdQnZZZFnbK8OtGmo/V94apXvyjjk/gabC7Q%3D',
#                     'proj:bbox': [399960.0, 6690240.0, 509760.0, 6800040.0],
#                     'proj:shape': [10980, 10980],
#                     'proj:transform': [10.0,
#                                        0.0,
#                                        399960.0,
#                                        0.0,
#                                        -10.0,
# ...

# %%
response = normalize_stac_item_to_imagery_search_response(item)

print(response)
print(response.model_dump())
# Out:
# id='S2A_MSIL2A_20190717T213531_R086_T06VVN_20201005T152616' datetime='2019-07-17T21:35:31.024000Z' platform='Sentinel-2A' collection='sentinel-2-l2a' geometry=PolygonGeometry(type='Polygon', coordinates=[[(-148.2261, 61.3255794), (-148.28297, 61.2614351), (-148.40121, 61.121331), (-148.51688, 60.9808236), (-148.63188, 60.8404682), (-148.74884, 60.7008454), (-148.82765, 60.6064378), (-148.86876, 61.3215913), (-148.2261, 61.3255794)]]) proj_code='EPSG:32606' cloud_cover=7.059297
# {'id': 'S2A_MSIL2A_20190717T213531_R086_T06VVN_20201005T152616', 'datetime': '2019-07-17T21:35:31.024000Z', 'platform': 'Sentinel-2A', 'collection': 'sentinel-2-l2a', 'geometry': {'type': 'Polygon', 'coordinates': [[(-148.2261, 61.3255794), (-148.28297, 61.2614351), (-148.40121, 61.121331), (-148.51688, 60.9808236), (-148.63188, 60.8404682), (-148.74884, 60.7008454), (-148.82765, 60.6064378), (-148.86876, 61.3215913), (-148.2261, 61.3255794)]]}, 'proj_code': 'EPSG:32606', 'cloud_cover': 7.059297}

# %%
search = catalog.search(
    collections=["landsat-c2-l2"],
    intersects=area_of_interest,
    datetime=time_of_interest,
    query={"eo:cloud_cover": {"lt": 10}},
)

items = search.item_collection()

print("LANDSAT")
print("Count:", len(items))

item = items[0]

from pprint import pprint

pprint(item.to_dict())
print("ID:", item.id)
print("Collection:", item.collection_id)
print("Properties:", item.properties)
print("Assets:", item.assets.keys())
# Out:
# LANDSAT
# Count: 11
# {'assets': {'ang': {'description': 'Collection 2 Level-1 Angle Coefficients '
#                                    'File',
#                     'href': 'https://landsateuwest.blob.core.windows.net/landsat-c2/level-2/standard/oli-tirs/2019/068/018/LC08_L2SP_068018_20190730_20200827_02_T1/LC08_L2SP_068018_20190730_20200827_02_T1_ANG.txt?st=2026-09-03T10%3A37%3A25Z&se=2026-09-04T11%3A22%3A25Z&sp=rl&sv=2025-07-05&sr=c&skoid=9c8ff44a-6a2c-4dfb-b298-1c9212f64d9a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2026-09-04T10%3A04%3A11Z&ske=2026-09-11T10%3A04%3A11Z&sks=b&skv=2025-07-05&sig=0GJTohB2lH%2BBXgIPIFHJxMvgsYj7g%2BxfeYgC%2BJH%2BRJ4%3D',
#                     'roles': ['metadata'],
#                     'title': 'Angle Coefficients File',
#                     'type': 'text/plain'},
#             'atran': {'description': 'Collection 2 Level-2 Atmospheric '
#                                      'Transmittance Band (ST_ATRAN) Surface '
# ...

# %%
response = normalize_stac_item_to_imagery_search_response(item)

print(response)
print(response.model_dump())
# Out:
# id='LC08_L2SP_068018_20190730_02_T1' datetime='2019-07-30T21:08:04.757100Z' platform='landsat-8' collection='landsat-c2-l2' geometry=PolygonGeometry(type='Polygon', coordinates=[[(-150.5240345, 61.185312), (-147.249672, 60.6429545), (-148.4376602, 58.9865693), (-151.5604412, 59.5120443), (-150.5240345, 61.185312)]]) proj_code='EPSG:32606' cloud_cover=9.6
# {'id': 'LC08_L2SP_068018_20190730_02_T1', 'datetime': '2019-07-30T21:08:04.757100Z', 'platform': 'landsat-8', 'collection': 'landsat-c2-l2', 'geometry': {'type': 'Polygon', 'coordinates': [[(-150.5240345, 61.185312), (-147.249672, 60.6429545), (-148.4376602, 58.9865693), (-151.5604412, 59.5120443), (-150.5240345, 61.185312)]]}, 'proj_code': 'EPSG:32606', 'cloud_cover': 9.6}

# %%
search = catalog.search(
    collections=["sentinel-1-grd"],
    intersects=area_of_interest,
    datetime=time_of_interest,
)

items = search.item_collection()

print("SENTINEL-1")
print("Count:", len(items))

item = items[0]

from pprint import pprint

pprint(item.to_dict())
print("ID:", item.id)
print("Collection:", item.collection_id)
print("Properties:", item.properties)
print("Assets:", item.assets.keys())
# Out:
# SENTINEL-1
# Count: 15
# {'assets': {'rendered_preview': {'href': 'https://planetarycomputer.microsoft.com/api/data/v1/item/preview.png?collection=sentinel-1-grd&item=S1B_IW_GRDH_1SDV_20190724T031934_20190724T031959_017270_0207AF&assets=vv&assets=vh&expression=vv%3Bvh%3Bvv%2Fvh&rescale=0%2C600&rescale=0%2C270&rescale=0%2C9&asset_as_band=True&tile_format=png&format=png',
#                                  'rel': 'preview',
#                                  'roles': ['overview'],
#                                  'title': 'Rendered preview',
#                                  'type': 'image/png'},
#             'safe-manifest': {'description': 'General product metadata in XML '
#                                              'format. Contains a high-level '
#                                              'textual description of the '
#                                              'product and references to all of '
# ...

# %%
response = normalize_stac_item_to_imagery_search_response(item)

print(response)
print(response.model_dump())
# Out:
# id='S1B_IW_GRDH_1SDV_20190724T031934_20190724T031959_017270_0207AF' datetime='2019-07-24T03:19:46.812361Z' platform='SENTINEL-1B' collection='sentinel-1-grd' geometry=PolygonGeometry(type='Polygon', coordinates=[[(-147.7381912, 61.0392033), (-147.296619, 61.0869037), (-147.0678137, 61.1109914), (-146.6091775, 61.158003), (-146.149205, 61.203457), (-145.9187294, 61.2255976), (-145.4568241, 61.2687017), (-144.9936796, 61.3102304), (-144.7616553, 61.3304018), (-144.2967284, 61.369555), (-143.8306653, 61.4071161), (-143.5972209, 61.4252978), (-143.1676966, 61.4576258), (-143.2089177, 61.6376286), (-143.2571043, 61.8172202), (-143.3319491, 61.9948994), (-143.4037639, 62.172819), (-143.4597543, 62.351893), (-143.518347, 62.5307942), (-143.5799847, 62.7094939), (-143.6428023, 62.8881264), (-143.6641321, 62.9469752), (-144.1151235, 62.9142223), (-144.3602014, 62.8957722), (-144.8494171, 62.8575983), (-145.3373368, 62.8177321), (-145.580795, 62.7971667), (-146.0666771, 62.7547762), (-146.5511
# ...

# %%
from satellite_imagery_viewer.stac.search import search_imagery
from satellite_imagery_viewer.models.imagery import ImagerySearchRequest

search_params = ImagerySearchRequest(
    collection="sentinel-2-l2a",
    area_of_interest={
        "type": "Polygon",
        "coordinates": [
            [
                [-122.522, 37.7045],
                [-122.356, 37.7045],
                [-122.356, 37.815],
                [-122.522, 37.815],
                [-122.522, 37.7045]
            ]
        ]
    },
    time_range="2023-01-01/2023-12-31",
    cloud_cover=20
)

items = search_imagery(search_params)
print(items)
# Out:
# <class 'dict'>
# {'type': 'Polygon', 'coordinates': [[[-122.522, 37.7045], [-122.356, 37.7045], [-122.356, 37.815], [-122.522, 37.815], [-122.522, 37.7045]]]}
# ...

# %%
from satellite_imagery_viewer.services.discovery import discover_imagery
from satellite_imagery_viewer.models.imagery import ImagerySearchRequest, ImagerySearchResponse
from satellite_imagery_viewer.stac.search import search_imagery
from satellite_imagery_viewer.stac.normalizer import normalize_stac_item_to_imagery_search_response

search_params = ImagerySearchRequest(
    collection="sentinel-2-l2a",
    area_of_interest={
        "type": "Polygon",
        "coordinates": [
            [
                [-122.522, 37.7045],
                [-122.356, 37.7045],
                [-122.356, 37.815],
                [-122.522, 37.815],
                [-122.522, 37.7045]
            ]
        ]
    },
    time_range="2023-01-01/2023-12-31",
    cloud_cover=20
)

results = discover_imagery(search_params)
for result in results:
    print(result)
# Out:
# <class 'dict'>
# {'type': 'Polygon', 'coordinates': [[[-122.522, 37.7045], [-122.356, 37.7045], [-122.356, 37.815], [-122.522, 37.815], [-122.522, 37.7045]]]}
# id='S2B_MSIL2A_20231130T185739_R113_T10SEG_20241031T042024' datetime='2023-11-30T18:57:39.024000Z' platform='Sentinel-2B' collection='sentinel-2-l2a' geometry=PolygonGeometry(type='Polygon', coordinates=[[(-123.0002276, 37.9475896), (-121.7506457, 37.9409562), (-121.7669948, 36.9514795), (-123.0002247, 36.9578811), (-123.0002276, 37.9475896)]]) proj_code='EPSG:32610' cloud_cover=8.262773
# id='S2B_MSIL2A_20231130T185739_R113_T10SEG_20231130T222154' datetime='2023-11-30T18:57:39.024000Z' platform='Sentinel-2B' collection='sentinel-2-l2a' geometry=PolygonGeometry(type='Polygon', coordinates=[[(-123.0002276, 37.9475896), (-121.7506457, 37.9409562), (-121.7669948, 36.9514795), (-123.0002247, 36.9578811), (-123.0002276, 37.9475896)]]) proj_code='EPSG:32610' cloud_cover=10.689344
# ...

# %%
from satellite_imagery_viewer.services.discovery import discover_imagery
from satellite_imagery_viewer.models.imagery import ImagerySearchRequest, ImagerySearchResponse
from satellite_imagery_viewer.stac.search import search_imagery
from satellite_imagery_viewer.stac.normalizer import normalize_stac_item_to_imagery_search_response

search_params = ImagerySearchRequest(
    collection="landsat-c2-l2",
    area_of_interest={
        "type": "Polygon",
        "coordinates": [
            [
                [-122.522, 37.7045],
                [-122.356, 37.7045],
                [-122.356, 37.815],
                [-122.522, 37.815],
                [-122.522, 37.7045]
            ]
        ]
    },
    time_range="2023-01-01/2023-12-31",
    cloud_cover=20
)

results = discover_imagery(search_params)
print(len(results))
for result in results[:3]:
    print(result)
# Out:
# <class 'dict'>
# {'type': 'Polygon', 'coordinates': [[[-122.522, 37.7045], [-122.356, 37.7045], [-122.356, 37.815], [-122.522, 37.815], [-122.522, 37.7045]]]}
# 31
# id='LC09_L2SP_045034_20231223_02_T1' datetime='2023-12-23T18:52:36.315511Z' platform='landsat-9' collection='landsat-c2-l2' geometry=PolygonGeometry(type='Polygon', coordinates=[[(-124.47398482876063, 38.520566315583075), (-124.96324114286224, 36.801180719169786), (-122.92945178117769, 36.41331477426564), (-122.39246158792513, 38.13163795748129), (-124.47398482876063, 38.520566315583075)]]) proj_code='EPSG:32610' cloud_cover=3.8
# ...

# %%
from satellite_imagery_viewer.services.discovery import discover_imagery
from satellite_imagery_viewer.models.imagery import ImagerySearchRequest, ImagerySearchResponse
from satellite_imagery_viewer.stac.search import search_imagery
from satellite_imagery_viewer.stac.normalizer import normalize_stac_item_to_imagery_search_response

search_params = ImagerySearchRequest(
    collection="sentinel-1-grd",
    area_of_interest={
        "type": "Polygon",
        "coordinates": [
            [
                [-122.522, 37.7045],
                [-122.356, 37.7045],
                [-122.356, 37.815],
                [-122.522, 37.815],
                [-122.522, 37.7045]
            ]
        ]
    },
    time_range="2023-01-01/2023-12-31",
    cloud_cover=20
)

results = discover_imagery(search_params)
print(len(results))
for result in results[:3]:
    print(result)
# Out:
# <class 'dict'>
# {'type': 'Polygon', 'coordinates': [[[-122.522, 37.7045], [-122.356, 37.7045], [-122.356, 37.815], [-122.522, 37.815], [-122.522, 37.7045]]]}
# 0

# %%
for collection_id in [
    "sentinel-2-l2a",
    "landsat-c2-l2",
    "sentinel-1-grd",
]:

    collection = catalog.get_collection(collection_id)
    queryables = collection.get_queryables()

    print(f"\n{collection_id}")
    for field in queryables["properties"]:
        print(field)
# Out:
# sentinel-2-l2a
# id
# datetime
# geometry
# proj:epsg
# instruments
# end_datetime
# s2:mgrs_tile
# constellation
# s2:granule_id
# eo:cloud_cover
# s2:datatake_id
# s2:product_uri
# start_datetime
# s2:datastrip_id
# s2:product_type
# sat:orbit_state
# s2:datatake_type
# s2:generation_time
# sat:relative_orbit
# s2:water_percentage
# s2:mean_solar_zenith
# s2:mean_solar_azimuth
# s2:processing_baseline
# s2:snow_ice_percentage
# s2:vegetation_percentage
# s2:thin_cirrus_percentage
# s2:cloud_shadow_percentage
# s2:nodata_pixel_percentage
# s2:unclassified_percentage
# s2:dark_features_percentage
# s2:not_vegetated_percentage
# s2:degraded_msi_data_percentage
# s2:high_proba_clouds_percentage
# s2:reflectance_conversion_factor
# s2:medium_proba_clouds_percentage
# s2:saturated_defective_pixel_percentage
#
# landsat-c2-l2
# id
# gsd
# created
# sci:doi
# datetime
# geometry
# platform
# proj:epsg
# instrument
# proj:shape
# description
# instruments
# end_datetime
# eo:cloud_cover
# ...

# %%
collection = catalog.get_collection("sentinel-1-grd")

print(collection.summaries.to_dict())
# Out:
# {'platform': ['SENTINEL-1A', 'SENTINEL-1B', 'SENTINEL-1C'], 'constellation': ['Sentinel-1'], 's1:resolution': ['full', 'high', 'medium'], 's1:orbit_source': ['DOWNLINK', 'POEORB', 'PREORB', 'RESORB'], 'sar:looks_range': [5, 6, 3, 2], 'sat:orbit_state': ['ascending', 'descending'], 'sar:product_type': ['GRD'], 'sar:looks_azimuth': [1, 6, 2], 'sar:polarizations': [['VV', 'VH'], ['HH', 'HV'], ['VV'], ['VH'], ['HH'], ['HV']], 'sar:frequency_band': ['C'], 's1:processing_level': ['1'], 'sar:instrument_mode': ['IW', 'EW', 'SM'], 'sar:center_frequency': [5.405], 'sar:resolution_range': [20, 23, 50, 93, 9], 's1:product_timeliness': ['NRT-10m', 'NRT-1h', 'NRT-3h', 'Fast-24h', 'Off-line', 'Reprocessing'], 'sar:resolution_azimuth': [22, 23, 50, 87, 9], 'sar:pixel_spacing_range': [10, 25, 40, 3.5], 'sar:observation_direction': ['right'], 'sar:pixel_spacing_azimuth': [10, 25, 40, 3.5], 'sar:looks_equivalent_number': [4.4, 29.7, 2.7, 10.7, 3.7], 'sat:platform_international_designator': ['2014-016A'
# ...
